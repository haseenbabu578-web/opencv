# %% [markdown]
# <a href="https://colab.research.google.com/github/haseenbabu578-web/opencv/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# Correcting image paths and loading images
img1 = cv2.imread("/content/images.jpg")
img2 = cv2.imread("/content/72f1d3064f1b68c8ce9ea00aeea3886c.jpg")
img3 = cv2.imread("/content/anupama-celebrity-model-actress-indian-actors-hd-wallpaper-preview.jpg")
img4 = cv2.imread("/content/HD-wallpaper-sai-pallavi-actor-india-actor-thumbnail.jpg")

# Display images only if they are loaded successfully
if img1 is not None: cv2_imshow(img1)
else: print("Error: img1 not loaded.")

if img2 is not None: cv2_imshow(img2)
else: print("Error: img2 not loaded.")

if img3 is not None: cv2_imshow(img3)
else: print("Error: img3 not loaded.")

if img4 is not None: cv2_imshow(img4)
else: print("Error: img4 not loaded.")

cv2.waitKey(1000)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=201x251>

# %% [markdown]
# # New Section
